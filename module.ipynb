# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/NathanaelAckerman/ML_MOOC_Yannis/blob/master/module.ipynb)

# %%
  import numpy as np
  import pandas as pd
  import matplotlib.pyplot as plt
  from io import StringIO

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e0ce39be-8de5-4c8b-9d73-bcbc219cc4e5" name="files[]" multiple disabled />
#      <output id="result-e0ce39be-8de5-4c8b-9d73-bcbc219cc4e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
house_data = pd.read_csv(StringIO(uploaded['house.csv'].decode('utf_8')))
house_data = house_data[house_data['surface'] < 200]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-492b61cfd899> in <module>()
# ----> 1 house_data = pd.read_csv(StringIO(uploaded['house.csv'].decode('utf_8')))
#       2 house_data = house_data[house_data['surface'] < 200]
#
# KeyError: 'house.csv'

# %%
plt.plot(house_data['surface'], house_d ata['loyer'], 'ro', markersize=4)
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(np.array([house_data['surface']]).T, np.array([house_data['loyer']]).T)
print(str(regr.coef_) + " " + str(regr.intercept_))
# Out:
# [[33.61347533]] [121.60147133]

# %%
plt.xlabel('Surface')
plt.ylabel('Loyer')

plt.plot(house_data['surface'], house_data['loyer'], 'ro', markersize=4)

# On affiche la droite entre 0 et 250
plt.plot([0,250], [regr.predict(np.array([[0]]))[0], regr.predict(np.array([[250]]))[0]], linestyle='--', c='#000000')

plt.show()

# %%
regr.predict(np.array([[0]]))
# Out:
# array([[121.60147133]])
